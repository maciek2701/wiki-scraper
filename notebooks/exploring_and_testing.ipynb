# %% [markdown]
# Notebook used during development of repo

# %%
# %load_ext autoreload
# %autoreload 2

# %%
### Imports
from wikiscraper.scraper.client import WikiClient
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 2
#       1 ### Imports
# ----> 2 from wikiscraper.scraper.client import WikiClient
#
# ModuleNotFoundError: No module named 'wikiscraper'

# %%
### 1 krok budowania projektu

rocket_source = 'fixtures/Team_Rocket.html'

# %%
wikiclient = WikiClient(rocket_source)
